# %%
import pandas as pd

df_details = pd.read_csv('details_of_assembly_segment_2019.csv')
df_details.head()
# Out:
#        state_name constituency_name assembly_constituency_name  nota_votes  \
# 0  Andhra Pradesh            Aruku              Palakonda (ST)        3736
# 1  Andhra Pradesh            Aruku              Palakonda (ST)        3736
# 2  Andhra Pradesh            Aruku              Palakonda (ST)        3736
# 3  Andhra Pradesh            Aruku              Palakonda (ST)        3736
# 4  Andhra Pradesh            Aruku              Palakonda (ST)        3736
#
#                                       candidate_name party_name  secured_votes
# 0                                KISHORE CHANDRA DEO        TDP        54056.0
# 1  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...        BJP         1753.0
# 2                                   GODDETI. MADHAVI      YSRCP        69588.0
# 3                             SHRUTI DEVI VYRICHERLA        INC         1327.0
# 4                                GANGULAIAH VAMPURU.        JnP         2987.0

# %%
scam = df_details.isna().sum()
scam
# Out:
# state_name                     0
# constituency_name              0
# assembly_constituency_name     0
# nota_votes                     0
# candidate_name                 0
# party_name                     0
# secured_votes                 15
# dtype: int64

# %%
df_details.fillna(0, inplace= True)
scam = df_details.isna().sum()
scam
# Out:
# state_name                    0
# constituency_name             0
# assembly_constituency_name    0
# nota_votes                    0
# candidate_name                0
# party_name                    0
# secured_votes                 0
# dtype: int64

# %%
df_details.to_csv('details_of_assembly_segment_2019_updated.csv', index=False)

# %%
import pandas as pd

df = pd.read_csv('details_of_assembly_segment_2019_updated.csv')
df.head()
# Out:
#        state_name constituency_name assembly_constituency_name  nota_votes  \
# 0  Andhra Pradesh            Aruku              Palakonda (ST)        3736
# 1  Andhra Pradesh            Aruku              Palakonda (ST)        3736
# 2  Andhra Pradesh            Aruku              Palakonda (ST)        3736
# 3  Andhra Pradesh            Aruku              Palakonda (ST)        3736
# 4  Andhra Pradesh            Aruku              Palakonda (ST)        3736
#
#                                       candidate_name party_name  secured_votes
# 0                                KISHORE CHANDRA DEO        TDP        54056.0
# 1  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...        BJP         1753.0
# 2                                   GODDETI. MADHAVI      YSRCP        69588.0
# 3                             SHRUTI DEVI VYRICHERLA        INC         1327.0
# 4                                GANGULAIAH VAMPURU.        JnP         2987.0

# %%
list_of_parties = list(df['party_name'].unique())
list_of_parties.sort()
len(list_of_parties)
# Out:
# 673

# %%
print(list_of_parties)
# Out:
# ['AAAP', 'AABHAP', 'AACP', 'AAHPty', 'AAM', 'AAPP', 'ABD', 'ABEP', 'ABGP', 'ABHM', 'ABHP', 'ABHS', 'ABJS', 'ABLP', 'ABML(S)', 'ABMP', 'ABNNP', 'ABSKP', 'ABSSP', 'ACDP', 'ACP', 'ADAL', 'ADMK', 'ADPT', 'ADRP', 'ADRSP', 'ADUP', 'AGP', 'AHFBK', 'AHIMSASP', 'AHNP', 'AIDMMK', 'AIFB', 'AIJAP', 'AIMAK', 'AIMF', 'AIMIM', 'AINHCP', 'AINPP', 'AINRC', 'AIP', 'AIPF', 'AIPTMMK', 'AIRCP', 'AITC', 'AIUC', 'AIUDF', 'AIUUK', 'AIVP', 'AJM', 'AJNSP', 'AJPI', 'AJPR', 'AJSUP', 'AKBHAD', 'AKBJHP', 'AKBMP', 'AKHP', 'AKSP', 'ALHP', 'ALINLBP', 'ALoP', 'AMB', 'AMKP', 'AMPK', 'AMiP', 'ANC', 'ANIJP', 'ANNADATA', 'ANRP', 'ANSP', 'APEP', 'APKSP', 'APoI', 'ARK', 'ARP', 'ARPS', 'ASDC', 'ASDHP', 'ASGP', 'ASJP', 'ASP', 'ASaP', 'ATBP', 'AVIRP', 'AVVP', 'AYP', 'AYSRCP', 'AgIMK', 'AlPP', 'AnAP', 'BAAP', 'BAEP', 'BAHUMP', 'BALP', 'BARESP', 'BARP', 'BAWPA', 'BBC', 'BBKD', 'BBM', 'BBMP', 'BBPP', 'BCUF', 'BDJS', 'BDPty', 'BDlP', 'BEPP', 'BGanP', 'BHABHAPA', 'BHAIP', 'BHAPRAP', 'BHAZS', 'BHBHP', 'BHBP', 'BHHF', 'BHJMP', 'BHMP
# ...

# %%
df_eci = pd.read_csv('eci_data_2024_updated.csv')
df_eci.head()
# Out:
#    s_no      candidate_name                           party_name EVM_votes  \
# 0     1     BISHNU PADA RAY               Bharatiya Janata Party    102182
# 1     2  KULDEEP RAI SHARMA             Indian National Congress     77829
# 2     3          MANOJ PAUL  Andaman Nicobar Democratic Congress      8236
# 3     4          D AYYAPPAN   Communist Party of India (Marxist)      6009
# 4     5     V.K. ABDUL AZIZ                          Independent      2195
#
#   Postal_votes secured_votes percentage_of_votes                 state_name  \
# 0          254        102436               50.58  Andaman & Nicobar Islands
# 1          211         78040               38.54  Andaman & Nicobar Islands
# 2           18          8254                4.08  Andaman & Nicobar Islands
# 3            8          6017                2.97  Andaman & Nicobar Islands
# 4            8          2203                1.09  Andaman & Nicobar Islands
#
#                constituency_name
# ...

# %%
list_of_party_eci = list(df_eci['party_name'].unique())
list_of_party_eci.sort()
len(list_of_party_eci)
# Out:
# 746

# %%
print(list_of_party_eci)
# Out:
# ['AARAKSHAN VIRODHI PARTY', 'AJSU Party', 'Aadarsh Mithila Party', 'Aadarsh Sangram Party', 'Aadi Bharat Party', 'Aadim Samaj Party', 'Aam Aadmi Parivartan Party', 'Aam Aadmi Party', 'Aam Janmat Party,', 'Aam Janshakti Party', 'Aam Janta Party (India)', 'Aam Janta Party Rashtriya', 'Aam Lok Party United', 'Aanaithinthiya Jananayaka Pathukappu Kazhagam', 'Aap Sabki Apni Party', 'Aapka Gantantra Party', 'Aapki Apni Party (Peoples)', 'Aapki Awaaz Party', 'Aas Punjab Party', 'Aawami Pichhada Party', 'Aazad Samaj Party (Kanshi Ram)', 'Abhay Samaj Party', 'Abhinav Bharat Janseva Paksh', 'Abhinav Rajasthan Party', 'Abua Jharkhand Party', 'Adarsh Jankalyan Dal', 'Adarsh Janta Party,', 'Adarsh Nyay Rakshak Party', 'Adarsh Samaj Party', 'Adarshwaadi Congress Party', 'Adim Bhartiya Dal', 'Ahimsa Socialist Party', 'Ahinsa Samaj Party', 'Aihra National Party', 'Aim Political Party', 'Akhand Bharat Janpriya Party', 'Akhand Bharat Samrajya Party', 'Akhand Bharat Swatantra Party', 'Akhil Bharat Hind
# ...

# %%
number_of_occurrences = dict(df_eci['party_name'].value_counts())
for k,v in number_of_occurrences.items():
    print(k,v)
# Out:
# Independent 3920
# None of the Above 542
# Bahujan Samaj Party 488
# Bharatiya Janata Party 441
# Indian National Congress 328
# Socialist Unity Centre Of India (COMMUNIST) 150
# Peoples Party of India (Democratic) 79
# Samajwadi Party 71
# Communist Party of India (Marxist) 52
# All India Trinamool Congress 48
# Bharatheeya Jawan Kisan Party 41
# Naam Tamilar Katchi 40
# Bhartiya Shakti Chetna Party 40
# Ambedkarite Party of India 38
# Vanchit Bahujan Aaghadi 38
# All India Anna Dravida Munnetra Kazhagam 36
# Akhil Bhartiya Parivar Party 36
# All India Forward Bloc 33
# Right to Recall Party 33
# Communist Party of India 30
# Bahujan Mukti Party 28
# Karnataka Rashtra Samithi 28
# Pyramid Party of India 26
# Aazad Samaj Party (Kanshi Ram) 26
# Yuvajana Sramika Rythu Congress Party 25
# Rashtriya Janata Dal 24
# Republican Party of India (A) 23
# Sardar Patel Siddhant Party 23
# Gondvana Gantantra Party 23
# Samata Party 22
# Aam Aadmi Party 22
# Bharat Adivasi Party 22
# ...

# %%
number_of_occurrences_19 = dict(df['party_name'].value_counts())
for k,v in number_of_occurrences_19.items():
    print(k,v)
# Out:
# IND 25037
# BJP 3353
# INC 3339
# BSP 2691
# SUCI(C) 861
# BMUP 816
# CPIM 741
# SHS 705
# APoI 594
# PSPL 526
# AITC 461
# PPID 418
# PPOI 357
# BHAPRAP 355
# CPI 351
# HND 338
# AIFB 302
# AAAP 301
# VBA 282
# SP 269
# BSCP 263
# RPI(A) 263
# NTK 258
# MNM 246
# NCP 236
# UPJP 216
# NPEP 205
# JD(U) 180
# CPI(ML)(L) 177
# AAPP 175
# TDP 175
# YSRCP 175
# GGP 169
# JnP 168
# BARESP 163
# BJD 147
# VPI 145
# DMK 144
# ANC 142
# ADMK 132
# BAHUMP 130
# BTP 129
# RJD 126
# SBSP 126
# TRS 119
# JANADIP 118
# JD(S) 116
# PUJP 108
# JKNPP 108
# AMB 107
# RTORP 105
# SDPI 98
# TNLK 96
# SPAKP 94
# BKNP 93
# ACDP 92
# SAD 90
# INLD 90
# IPBP 87
# RJBP 85
# JMM 83
# SMFB 76
# JPJD 75
# BLSD 74
# PBI 73
# HSS 73
# PECP 73
# SatBP 68
# RSPS 67
# MADP 66
# RasLP 64
# JNJP 63
# HBP 62
# RRP 61
# NDPP 60
# DMSK 60
# NEINDP 60
# IPFT 60
# PPA 60
# IUML 59
# RJsbhP 58
# NRCP 58
# RJSPS 58
# BMFP 57
# UKKD 56
# UKDD 56
# AgIMK 55
# ssrd 55
# AHNP 54
# ASP 52
# SGUP 52
# SABHP 51
# MKDVP 50
# ...
